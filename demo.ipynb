# %%
# !git clone https://github.com/Tospros/rse-assignment.git
# Out:
# Cloning into 'rse-assignment'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 82 (delta 4), reused 79 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 596.43 KiB | 5.52 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd rse-assignment
# !pip install -e .

import sys
import os

# Add the repository root's 'src' directory to sys.path to ensure modules are discoverable.
# This is often needed in notebooks for editable installs when the package is in 'src'.
repo_src_root = '/content/rse-assignment/src'
if repo_src_root not in sys.path:
    sys.path.insert(0, repo_src_root)

print(f"sys.path updated with {repo_src_root}")

# Change back to the content directory if the user wishes to proceed with further tasks
# %cd /content
# Out:
# /content/rse-assignment
# Obtaining file:///content/rse-assignment
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 6.1 MB/s eta 0:00:00
# ...
#   Building editable for physics-units (pyproject.toml) ... done
#   Created wheel for physics-units: filename=physics_units-0.1.0-0.editable-py3-none-any.whl size=1440 sha256=10b6e1f43ae6136d03b3f22b018e93200d4e5cea6708730fc811ae31ee93f3b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m0t_4yrh/wheels/fb/6d/ce/18dbee27d3bbeb67804c514e28aa0d49d87165e2313c100093
# Successfully built physics-units
# ...
# sys.path updated with /content/rse-assignment/src

# %%
# !pip install pint
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from physics_units import speed

print(speed(100, 9.58))
# Out:
# 10.438413361169102 meter / second
